# %%
import numpy as np
import pandas as pd
import pickle as pk
import seaborn as sns
import sklearn.cluster as cluster
import string as st
import warnings
from imblearn.under_sampling import NearMiss
from imblearn.over_sampling import RandomOverSampler
from kneed import KneeLocator
from matplotlib import pyplot as plt
import nltk
from nltk.tokenize import sent_tokenize as stt
from nltk.tokenize import word_tokenize as wtt
from pandas.core.dtypes.common import is_numeric_dtype as is_num
import plotly.express as px
from sklearn import tree
from sklearn.cluster import KMeans
from sklearn.datasets import make_classification as mc
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import f_classif as fcf
from sklearn.metrics import accuracy_score as acc
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score as r2
from sklearn.model_selection import train_test_split as tts
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data Analysis

# %%
df = pd.read_excel('global_laptop_selling_data.xlsx')

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
df.describe()
# Out:
#          laptop_ID       Inches  Price_euros
# count  1303.000000  1303.000000  1303.000000
# mean    660.155794    15.017191  1123.686992
# std     381.172104     1.426304   699.009043
# min       1.000000    10.100000   174.000000
# 25%     331.500000    14.000000   599.000000
# 50%     659.000000    15.600000   977.000000
# 75%     990.500000    15.600000  1487.880000
# max    1320.000000    18.400000  6099.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
df.isnull().sum()
# Out:
# laptop_ID           0
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df.shape
# Out:
# (1303, 13)

# %%
df.columns
# Out:
# Index(['laptop_ID', 'Company', 'Product', 'TypeName', 'Inches',
#        'ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight',
#        'Price_euros'],
#       dtype='object')

# %%
df.dtypes
# Out:
# laptop_ID             int64
# Company              object
# Product              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price_euros         float64
# dtype: object

# %%
df.corr(numeric_only = True)
# Out:
#              laptop_ID    Inches  Price_euros
# laptop_ID     1.000000 -0.087796     0.067830
# Inches       -0.087796  1.000000     0.068197
# Price_euros   0.067830  0.068197     1.000000

# %%
df.nunique()
# Out:
# laptop_ID           1303
# Company               19
# Product              618
# TypeName               6
# Inches                18
# ScreenResolution      40
# Cpu                  118
# Ram                    9
# Memory                39
# Gpu                  106
# OpSys                  9
# Weight               179
# Price_euros          791
# dtype: int64

# %% [markdown]
# # Bar Plot

# %%
plt.figure(figsize = (20, 15))
sns.barplot(x = df['Company'].value_counts().index, y = df['Company'].value_counts().values, data = df, palette = 'rainbow', errcolor = 'black', errwidth = 2.0, capsize = 0.2).set_title('Company', fontsize = 50, color = 'black', loc = 'center', pad = 5.0, weight = 'bold')
plt.xlabel('Company', fontsize = 45, color = 'black', labelpad = 5.0)
plt.ylabel('Count', fontsize = 45,color = 'black', labelpad = 5.0)
plt.xticks(fontsize = 30,color = 'black',rotation = 90)
plt.yticks(fontsize = 30,color = 'black',rotation = 0)
plt.show()

# %% [markdown]
# #  Histplot

# %%
plt.figure(figsize = (20, 10))
sns.histplot(df['Price_euros'], kde = True, bins = 100, color = 'black', edgecolor = 'black', linewidth = 1.5, alpha = 0.5, label = 'Price_euros', element = 'step', fill = True).set_title('Price_euros Distribution', fontsize = 60,color = 'black', loc = 'center', pad = 5.0, weight = 'bold')
plt.xlabel('Price_euros', fontsize = 20,color = 'black', labelpad = 5.0)
plt.ylabel('Count', fontsize = 20, color = 'black', labelpad = 5.0)
plt.xticks(fontsize = 30,color = 'black')
plt.yticks(fontsize = 30,color = 'black')
plt.show()

# %% [markdown]
# #  Boxplot

# %%
plt.figure(figsize = (20,10))
sns.boxplot(x = df['Company'], y = df['Price_euros'], data = df, palette = 'rainbow', saturation = 1.0, width = 0.8, fliersize = 5.0, linewidth = 2.0, whis = 1.5).set_title('Companies - Price_euros ', fontsize = 50,color = 'black', loc = 'center', pad = 5.0, weight = 'bold')
plt.xlabel('Company', fontsize = 30,color = 'black', labelpad = 5.0)
plt.ylabel('Price_euros', fontsize = 30,color = 'black', labelpad = 5.0)
plt.xticks(fontsize = 20, color = 'black',rotation=90)
plt.yticks(fontsize = 20,color = 'black')
plt.show()

# %% [markdown]
# # Scatterplot

# %%
plt.figure(figsize = (20,10))
sns.scatterplot(x = df['Company'], y = df['Price_euros'], data = df, palette = 'rainbow', hue = df['Company'], size = df['Company'], sizes = (200, 400), alpha = 0.5).set_title('Companies and Price_euros Correlationship', fontsize = 40,color = 'black', loc = 'center', pad = 5.0, weight = 'bold')
plt.xlabel('Company', fontsize = 30,color = 'black', labelpad = 5.0)
plt.ylabel('Price_euros', fontsize = 30,color = 'black', labelpad = 5.0)
plt.xticks(fontsize = 15,color = 'black')
plt.yticks(fontsize = 15,color = 'black')
plt.legend(loc = 'upper right', fontsize = 15, facecolor = 'gray', edgecolor = 'gray', framealpha = 0.7)
plt.show()

# %% [markdown]
# # Heatmap

# %%
plt.figure(figsize = (20, 10))
sns.heatmap(df.corr(numeric_only = True), annot = True, fmt = '.2f', linewidths = 2.0, linecolor = 'gray', square = True, annot_kws = {'size': 15}, cbar = True, cbar_kws = {'shrink': 0.5}).set_title('Correlationship of Heatmap', fontsize = 20, color = 'black', loc = 'center', weight = 'bold')
plt.xticks(fontsize = 15,color = 'black')
plt.yticks(fontsize = 15,color = 'black')
plt.show()

# %% [markdown]
# #  Data Cleaning and Preprocessing

# %% [markdown]
# # 4.1 Handling Missing Values

# %%
df.isna().sum()
# Out:
# laptop_ID           0
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %% [markdown]
# *`[NO MISSING VALUES DETECTED]`*

# %% [markdown]
# ### **`#4.2 Handling Duplicates`**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# *`[NO DUPLICATE VALUES DETECTED]`*

# %% [markdown]
# # Min-Max Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mm = MinMaxScaler(feature_range = (0, 1))

# %%
df['Price_euros'] = mm.fit_transform(df[['Price_euros']])
df['Inches'] = mm.fit_transform(df[['Inches']])
df['laptop_ID'] = mm.fit_transform(df[['laptop_ID']])

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName    Inches  \
# 0   0.000000   Apple  MacBook Pro  Ultrabook  0.385542
# 1   0.000758   Apple  Macbook Air  Ultrabook  0.385542
# 2   0.001516      HP       250 G6   Notebook  0.662651
# 3   0.002274   Apple  MacBook Pro  Ultrabook  0.638554
# 4   0.003033   Apple  MacBook Pro  Ultrabook  0.385542
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# ...

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
for col in df.columns:
    if is_num(df[col]):
        continue
    else:
        df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    laptop_ID  Company  Product  TypeName    Inches  ScreenResolution  Cpu  \
# 0   0.000000        1      300         4  0.385542                23   65
# 1   0.000758        1      301         4  0.385542                 1   63
# 2   0.001516        7       50         3  0.662651                 8   74
# 3   0.002274        1      300         4  0.638554                25   85
# 4   0.003033        1      300         4  0.385542                23   67
#
#    Ram  Memory  Gpu  OpSys  Weight  Price_euros
# 0    8       4   56      8      38     0.196741
# 1    8       2   50      8      35     0.122353
# 2    8      16   52      4      74     0.067679
# 3    1      29    8      8      71     0.398895
# 4    8      16   57      8      38     0.275038

# %% [markdown]
# # Removing Irrelevant or Redundant Features

# %%
df.drop(['laptop_ID'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    Company  Product  TypeName    Inches  ScreenResolution  Cpu  Ram  Memory  \
# 0        1      300         4  0.385542                23   65    8       4
# 1        1      301         4  0.385542                 1   63    8       2
# 2        7       50         3  0.662651                 8   74    8      16
# 3        1      300         4  0.638554                25   85    1      29
# 4        1      300         4  0.385542                23   67    8      16
#
#    Gpu  OpSys  Weight  Price_euros
# 0   56      8      38     0.196741
# 1   50      8      35     0.122353
# 2   52      4      74     0.067679
# 3    8      8      71     0.398895
# 4   57      8      38     0.275038

# %% [markdown]
# # 5 Split the dataset

# %%
x = df.drop(['Price_euros'], axis = 1)
y = df['Price_euros']

# %%
xtrain, xtest, ytrain, ytest = tts(x, y, test_size = 0.3, random_state = 42)

# %% [markdown]
# # 6 Model Training and Evaluation

# %% [markdown]
# #  Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
lr_pred = lr.predict(xtest)
lr_pred
# Out:
# array([ 0.18973234,  0.17732542, -0.01928791,  0.20530792,  0.11270564,
#         0.18359922,  0.11613081,  0.08550865,  0.20379013,  0.05196408,
#         0.27312704,  0.06753604,  0.23189449,  0.01875286,  0.25935605,
#         0.18726885,  0.21735118,  0.19024629,  0.18330905,  0.25518626,
#         0.23664179,  0.17822795,  0.1369785 ,  0.13443349,  0.15507165,
#         0.21027039,  0.16420072,  0.15557569,  0.13784181,  0.14821806,
#         0.07427514,  0.19897307,  0.18818542,  0.11947393,  0.17844909,
#         0.23130292,  0.15601193,  0.01751228,  0.17809825, -0.00934892,
#         0.31982129,  0.1245491 ,  0.20664895,  0.2577461 ,  0.09146856,
#         0.14966043,  0.28827728,  0.10125593,  0.13796026,  0.17553165,
#         0.18042358, -0.00926522,  0.22621146,  0.12678339,  0.23329878,
#         0.18847956,  0.10124612,  0.14378697,  0.16022434,  0.20530792,
#         0.15960803,  0.24283845,  0.10571192,  0.19132631,  0.03354529,
# ...

# %%
lr_mse = mse(ytest, lr_pred)
lr_mse
# Out:
# 0.008894679285432

# %%
lr_mae = mae(ytest, lr_pred)
lr_mae
# Out:
# 0.06507123139790764

# %%
lr_acc = lr.score(xtest, ytest)
lr_acc
# Out:
# 0.4168720599326944

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor

# %%
dt = DecisionTreeRegressor()

# %%
dt.fit(xtrain, ytrain)
# Out:
# DecisionTreeRegressor()

# %%
dt_pred = dt.predict(xtest)
dt_pred
# Out:
# array([0.21957806, 0.21957806, 0.06329114, 0.12236287, 0.15628523,
#        0.22362869, 0.18751055, 0.05485232, 0.12236287, 0.02109705,
#        0.29113924, 0.07172996, 0.29113924, 0.10666498, 0.20810127,
#        0.24050633, 0.16455696, 0.11915612, 0.13080169, 0.28270042,
#        0.37552743, 0.09220591, 0.12986329, 0.01265823, 0.17400844,
#        0.20183966, 0.05248945, 0.05248945, 0.25248945, 0.13181435,
#        0.04810127, 0.25738397, 0.25586498, 0.18987342, 0.11578059,
#        0.13113924, 0.08624473, 0.05316456, 0.22568608, 0.0030211 ,
#        0.20337553, 0.06329114, 0.13586498, 0.1443038 , 0.06963713,
#        0.13181435, 0.21839662, 0.00621097, 0.1107173 , 0.21991561,
#        0.2742616 , 0.0458903 , 0.1021097 , 0.15628523, 0.12067511,
#        0.09367089, 0.00621097, 0.12986329, 0.1135865 , 0.12236287,
#        0.2785654 , 0.13113924, 0.03291139, 0.07409283, 0.02042194,
#        0.2742616 , 0.06664979, 0.12236287, 0.12067511, 0.47156118,
# ...

# %%
dt_mse = mse(ytest, dt_pred)
dt_mse
# Out:
# 0.005132610595140831

# %%
dt_mae = mae(ytest, dt_pred)
dt_mae
# Out:
# 0.042719121154240446

# %%
dt_acc = dt.score(xtest, ytest)
dt_acc
# Out:
# 0.6635102236441415

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()

# %%
rf.fit(xtrain, ytrain)
# Out:
# RandomForestRegressor()

# %%
rf_pred = rf.predict(xtest)
rf_pred
# Out:
# array([0.20048945, 0.22467679, 0.06282599, 0.12854407, 0.2152677 ,
#        0.2384242 , 0.1134341 , 0.06066149, 0.16948474, 0.03263467,
#        0.27028805, 0.09452106, 0.26677438, 0.09797453, 0.27830852,
#        0.20658601, 0.19138109, 0.15087053, 0.12839971, 0.30483511,
#        0.33775882, 0.09251121, 0.16240126, 0.02263869, 0.16767647,
#        0.19401789, 0.08093367, 0.07860567, 0.24210434, 0.13983565,
#        0.0500922 , 0.24982302, 0.25970149, 0.20175772, 0.12857668,
#        0.11697553, 0.09435696, 0.05128145, 0.18628145, 0.01439916,
#        0.22629357, 0.07945364, 0.18015173, 0.24740599, 0.06971912,
#        0.14156925, 0.26351022, 0.0109416 , 0.12183907, 0.22111171,
#        0.26089958, 0.07026128, 0.14553909, 0.18240609, 0.1343117 ,
#        0.19387041, 0.01089755, 0.14655411, 0.139557  , 0.12854407,
#        0.23609527, 0.11991449, 0.04714449, 0.07675237, 0.02410412,
#        0.29525873, 0.06495998, 0.13315774, 0.12988071, 0.4709295 ,
# ...

# %%
rf_mse = mse(ytest, rf_pred)
rf_mse
# Out:
# 0.0031319157180139737

# %%
rf_mae = mae(ytest, rf_pred)
rf_mae
# Out:
# 0.03234250100765311

# %%
rf_acc = rf.score(xtest, ytest)
rf_acc
# Out:
# 0.7946741526587595

# %% [markdown]
# # KNN Classifications

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import KNeighborsRegressor

# %%
knn = KNeighborsRegressor()

# %%
knn.fit(xtrain, ytrain)
# Out:
# KNeighborsRegressor()

# %%
knn_pred = knn.predict(xtest)
knn_pred
# Out:
# array([0.25103797, 0.20870886, 0.06801688, 0.14258228, 0.23091983,
#        0.22805063, 0.1202535 , 0.05485232, 0.1935865 , 0.06092793,
#        0.21994903, 0.09221671, 0.22204219, 0.10761181, 0.2861097 ,
#        0.14994093, 0.20398312, 0.14884489, 0.12140084, 0.28945148,
#        0.3440216 , 0.15191662, 0.13316456, 0.01556118, 0.16289857,
#        0.15551055, 0.11472034, 0.12511527, 0.24459072, 0.13625215,
#        0.05484017, 0.17495359, 0.22636287, 0.10720709, 0.09566245,
#        0.09161148, 0.09724895, 0.05451477, 0.19453806, 0.02295359,
#        0.27868354, 0.06325738, 0.12940624, 0.20324051, 0.06911122,
#        0.13625215, 0.33525738, 0.01556118, 0.08006481, 0.24323713,
#        0.25529114, 0.03911865, 0.18714194, 0.18757772, 0.0845573 ,
#        0.17606751, 0.01556118, 0.14329114, 0.23268928, 0.14258228,
#        0.2652935 , 0.09623595, 0.05896709, 0.09248945, 0.03131781,
#        0.29262447, 0.060587  , 0.05451477, 0.10264979, 0.21300219,
# ...

# %%
knn_mse = mse(ytest, knn_pred)
knn_mse
# Out:
# 0.0055274297240328115

# %%
knn_mae = mae(ytest, knn_pred)
knn_mae
# Out:
# 0.0435684168042561

# %%
knn_acc = knn.score(xtest, ytest)
knn_acc
# Out:
# 0.6376262026534099

# %% [markdown]
# # SVR

# %%
from sklearn.svm import SVR

# %%
svr = SVR()

# %%
svr.fit(xtrain, ytrain)
# Out:
# SVR()

# %%
svr_pred = svr.predict(xtest)
svr_pred
# Out:
# array([ 0.23053901,  0.22317223,  0.0054729 ,  0.21633046,  0.17032424,
#         0.23177811,  0.12384738,  0.12097743,  0.22827465,  0.06434636,
#         0.26495026,  0.14441627,  0.24419962,  0.10097167,  0.26586329,
#         0.20494046,  0.219809  ,  0.22508236,  0.15004066,  0.27839444,
#         0.2675073 ,  0.19026465,  0.16175799,  0.10740419,  0.16525506,
#         0.16684145,  0.14481827,  0.13660654,  0.18314467,  0.13558543,
#         0.08730656,  0.22469582,  0.24332913,  0.1037812 ,  0.18145911,
#         0.2308003 ,  0.17777047,  0.02004327,  0.20288877,  0.08727883,
#         0.32414045,  0.14523092,  0.21143447,  0.27111538,  0.0967631 ,
#         0.13711495,  0.25656527,  0.08564821,  0.15229765,  0.2208323 ,
#         0.20689975,  0.03171321,  0.23645294,  0.15266012,  0.18644953,
#         0.20447907,  0.08567813,  0.16626442,  0.20354298,  0.21633046,
#         0.18638194,  0.23929625,  0.10869009,  0.17407684,  0.06869045,
# ...

# %%
svr_mse = mse(ytest, svr_pred)
svr_mse
# Out:
# 0.00798516300938505

# %%
svr_mae = mae(ytest, svr_pred)
svr_mae
# Out:
# 0.06401405215203083

# %%
svr_acc = svr.score(xtest, ytest)
svr_acc
# Out:
# 0.47649920729680373

# %% [markdown]
# # Model Comparison

# %%
pred_compare = pd.DataFrame({'Actual': ytest, 'Linear Regression': lr_pred, 'Decision Tree': dt_pred, 'Random Forest': rf_pred, 'KNN': knn_pred, 'SVR': svr_pred})
pred_compare
# Out:
#         Actual  Linear Regression  Decision Tree  Random Forest       KNN  \
# 479   0.252827           0.189732       0.219578       0.200489  0.251038
# 1022  0.164557           0.177325       0.219578       0.224677  0.208709
# 298   0.054852          -0.019288       0.063291       0.062826  0.068017
# 1265  0.122363           0.205308       0.122363       0.128544  0.142582
# 774   0.180591           0.112706       0.156285       0.215268  0.230920
# ...        ...                ...            ...            ...       ...
# 672   0.145148           0.161503       0.291139       0.223136  0.215220
# 506   0.177215           0.150746       0.184810       0.216170  0.171421
# 668   0.182954           0.178852       0.128945       0.141421  0.153046
# 778   0.459916           0.278116       0.409283       0.434281  0.276489
# 723   0.588253           0.209736       0.443207       0.546234  0.446676
#
#            SVR
# 479   0.230539
# 1022  0.223172
# 298   0.005473
# ...

# %% [markdown]
# # The Line Plot is:

# %%
plt.figure(figsize = (20, 10))
sns.lineplot(data = pred_compare, palette = 'rainbow', linewidth = 2.0, dashes = False, markers = True).set_title('Actual vs Predicted', fontsize = 20,color = 'black', loc = 'center', pad = 10.0, weight = 'bold')
plt.xlabel('Index', fontsize = 20,color = 'black', labelpad = 10.0)
plt.ylabel('Price_euros', fontsize = 20,color = 'black', labelpad = 10.0)
plt.xticks(fontsize = 15,color = 'black')
plt.yticks(fontsize = 15,color = 'black')
plt.legend(loc = 'upper right', fontsize = 15, frameon = True, fancybox = True, shadow = True, facecolor = 'gray', edgecolor = 'black')
plt.show()

# %%
acc_compare = pd.DataFrame({'Model': ['Linear Regression', 'Decision Tree Regression', 'Random Forest Regression', 'KNN Regressor', 'SVR'], 'MSE': [lr_mse, dt_mse, rf_mse, knn_mse, svr_mse], 'MAE': [lr_mae, dt_mae, rf_mae, knn_mae, svr_mae], 'Accuracy': [lr_acc, dt_acc, rf_acc, knn_acc, svr_acc]})
acc_compare
# Out:
#                       Model       MSE       MAE  Accuracy
# 0         Linear Regression  0.008895  0.065071  0.416872
# 1  Decision Tree Regression  0.005133  0.042719  0.663510
# 2  Random Forest Regression  0.003132  0.032343  0.794674
# 3             KNN Regressor  0.005527  0.043568  0.637626
# 4                       SVR  0.007985  0.064014  0.476499

# %%
plt.figure(figsize = (20, 10))
sns.barplot(x = 'Model', y = 'Accuracy', data = acc_compare, palette = 'rainbow', linewidth = 2.0, edgecolor = 'black').set_title('Accuracy Comparison', fontsize = 20,color = 'black', loc = 'center', pad = 10.0, weight = 'bold')
plt.xlabel('Model', fontsize = 20,color = 'black', labelpad = 10.0)
plt.ylabel('Accuracy', fontsize = 20,color = 'black', labelpad = 10.0)
plt.xticks(fontsize = 15,color = 'black')
plt.yticks(fontsize = 15,color = 'black')
plt.show()
